# %% [markdown]
# https://www.hello-statisticians.com/practice/stat_practice15.html

# %% [markdown]
# https://www.youtube.com/watch?v=wwZyRqH2Fo4&list=PLoT4uZPqN2DKP7_6fWsTW9ynM7uw7w0uD&index=10
# 最初の解説から回答まで。
# わかりやすいけど、いつ使うん？的なのはある。捨てたくはないけど、やはりここは後回しでもいい気がするやつ。対数変換とかロジスティック変換とかがキモかも
