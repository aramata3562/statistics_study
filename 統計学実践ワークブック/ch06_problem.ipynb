# %% [markdown]
# ### 例題 6.1

# %% [markdown]
# 1.
#
# A君とB君の標準化得点を求める
#
# Aくん
# $$
# \frac{(85-65)}{10} = 2
# $$
# Bくん
# $$
# \frac{(60-65)}{10} = -0.5
# $$
# これより、偏差値はそれぞれ
# $$
# 50+10*2=70
# $$
# $$
# 50+10(-0.5)=45
# $$
#
# 2.
# 標準化得点をそのまま$Z$の範囲で使えばいいので
# $$
# P(-0.5<Z≤2)=0.6687
# $$
#
# 3.
# 下側25%点を求めると
# $$
# 0.25 = P(X≤x_{0.25})=P(\frac{X-65}{10}≤\frac{x_{0.25}-65}{10})
# $$
# これを求めると、下側25%点は-0.0675
#
# 上側25%点は0.0675になる
#
# よって四分位範囲は
#
# $$
# (65+0.675*10)-(65-0.675*10)=13.5
# $$
#
# よって14点

# %% [markdown]
# ### 例題 6.2
#
# [2]がわからなすぎる。条件付き期待値、分散のあたりの計算

# %% [markdown]
# ### 例題 6.3
#
# ある医学研究で、患者が登録された時点から死亡までの時間 $t$ に関する生存関数 $S(t)$ について、パラメータ $\lambda$ をもつ関数 $S(t)$ を次のように仮定した。
#
# $S(t) = P(T > t) = \exp(-\lambda t)$
#
# 1. 確率変数 $T$ の確率密度関数 $f(t)$ を求めよ。
#
# 2. 確率密度関数 $f(t)$ をもつ分布の平均と上側 25%点を求めよ。
#
# 3. 10 人の死亡までの時間を調べ、確率変数 $T$ の標準平均を求めたところ 3.0 年となった。（2）の結果に基づき、$T$ の上側 25% の推定値を求めるということになった。$\lambda$ をいくらにすればよいか。必要に応じて、$\log 2 \approx 0.7, \log 4 \approx 1.4$ を用いてよい。

# %% [markdown]
# ### 例題 6.4
#
# ある大学の文学部および理学部における統計学の講義の受講生は 500 名のうち、300 名が文学部生であり、200 名が理学部生であるとする。期末試験は 100 点満点で、過去 10 年間の学生で、500 名全員が期末試験を受験した結果、文学部生の得点は正規分布 $N(65, 4^2)$ に従い、理学部生の得点は正規分布 $N(85, 3^2)$ に従うという 2 つの正規分布の混合正規分布であったことが分かった。
#
# 1. この期末試験において、文学の A さんは 67 点、理学の B さんは 82 点であった。文学の学生の中における A さんの偏差値と、理学の学生の中における B さんの偏差値はいくらか。
#
# 2. この期末試験では 60 点以上を合格とした。この試験の合格率はおよそ何 % か。
